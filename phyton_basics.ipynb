# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
x=5
print(x)
print("Value of x is :",x)
print(type(x))
# Out:
# 5
# Value of x is : 5
# <class 'int'>

# %%
x='p'
print(x)
print(type(x))
# Out:
# p
# <class 'str'>
